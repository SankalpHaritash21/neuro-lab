# %%
print("Hi")
# Out:
# Hi

# %% [markdown]
# ## Implement custom operations in PyTorch by using deep learning via gradient descent;
#
# <!-- 1. recursive chain rule (backpropagation)
# 2. bias-variance tradeoff
# 3. regularization -->
# output units: linear, softmax; hidden units: tanh, RELU.

# %%
# !pip install torch torchvision matplotlib
# Out:
# Requirement already satisfied: torch in c:\users\sankl\onedrive\documents\neuro-lab\venv\lib\site-packages (2.9.0)
# Requirement already satisfied: torchvision in c:\users\sankl\onedrive\documents\neuro-lab\venv\lib\site-packages (0.24.0)
# Requirement already satisfied: matplotlib in c:\users\sankl\onedrive\documents\neuro-lab\venv\lib\site-packages (3.10.7)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\sankl\onedrive\documents\neuro-lab\venv\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\sankl\onedrive\documents\neuro-lab\venv\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: filelock in c:\users\sankl\onedrive\documents\neuro-lab\venv\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: jinja2 in c:\users\sankl\onedrive\documents\neuro-lab\venv\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\sankl\onedrive\documents\neuro-lab\venv\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\sankl\onedrive\documents\neuro-lab\venv\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\sankl\onedrive\documents\neuro-lab\venv\lib\site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: numpy in c:\users\sankl\onedrive\documents\neuro-lab\venv\lib\site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sankl\onedrive\documents\neuro-lab\venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sankl\onedrive\documents\neuro-lab\venv\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sankl\onedrive\documents\neuro-lab\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sankl\onedrive\documents\neuro-lab\venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pyparsing>=3 in c:\users\sankl\onedrive\documents\neuro-lab\venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sankl\onedrive\documents\neuro-lab\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sankl\onedrive\documents\neuro-lab\venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: six>=1.5 in c:\users\sankl\onedrive\documents\neuro-lab\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sankl\onedrive\documents\neuro-lab\venv\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sankl\onedrive\documents\neuro-lab\venv\lib\site-packages (from jinja2->torch) (3.0.3)
# [notice] A new release of pip available: 22.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
import torch.nn as nn
from torch.autograd import Function
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# %%
# ---- Custom autograd Functions ----
class LinearFn(Function):
    @staticmethod
    def forward(ctx, x, w, b):
        ctx.save_for_backward(x, w, b)
        return x @ w.t() + b

    @staticmethod
    def backward(ctx, grad_out):
        x, w, b = ctx.saved_tensors
        grad_x = grad_out @ w
        grad_w = grad_out.t() @ x
        grad_b = grad_out.sum(0)
        return grad_x, grad_w, grad_b

class ReLUFn(Function):
    @staticmethod
    def forward(ctx, x):
        ctx.save_for_backward(x)
        return x.clamp(min=0)

    @staticmethod
    def backward(ctx, grad_out):
        x, = ctx.saved_tensors
        grad = grad_out.clone()
        grad[x < 0] = 0
        return grad

class TanhFn(Function):
    @staticmethod
    def forward(ctx, x):
        y = x.tanh()
        ctx.save_for_backward(y)
        return y

    @staticmethod
    def backward(ctx, grad_out):
        (y,) = ctx.saved_tensors
        return grad_out * (1 - y**2)

# %%
# ---- Layers using custom ops ----
class Linear(nn.Module):
    def __init__(self, in_f, out_f):
        super().__init__()
        self.w = nn.Parameter(torch.randn(out_f, in_f) * 0.1)
        self.b = nn.Parameter(torch.zeros(out_f))

    def forward(self, x):
        return LinearFn.apply(x, self.w, self.b)

class ReLU(nn.Module):
    def forward(self, x): return ReLUFn.apply(x)

class Tanh(nn.Module):
    def forward(self, x): return TanhFn.apply(x)

# %%
# ---- Training ----
def train(model, loader, lr=0.1, epochs=5, weight_decay=1e-4, device="cpu"):
    opt = torch.optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay)
    loss_fn = nn.CrossEntropyLoss()
    model.to(device)
    for ep in range(1, epochs+1):
        total, correct, loss_sum = 0,0,0
        for xb,yb in loader:
            xb,yb = xb.to(device), yb.to(device)
            opt.zero_grad()
            out = model(xb)
            loss = loss_fn(out, yb)
            loss.backward()
            opt.step()
            loss_sum += loss.item()*xb.size(0)
            correct += (out.argmax(1)==yb).sum().item()
            total += xb.size(0)
        print(f"Epoch {ep}: loss={loss_sum/total:.4f}, acc={correct/total:.4f}")

# %%
if __name__ == "__main__":
    transform = transforms.Compose([transforms.ToTensor()])
    trainset = datasets.MNIST(root="./data", train=True, download=True, transform=transform)
    loader = DataLoader(trainset, batch_size=128, shuffle=True)
    model = nn.Sequential(
        nn.Flatten(),
        Linear(28*28, 256),
        ReLU(),
        Linear(256, 128),
        Tanh(),
        Linear(128, 10)
    )
    train(model, loader, lr=0.1, epochs=5, weight_decay=1e-4)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 12
#       4 loader = DataLoader(trainset, batch_size=128, shuffle=True)
#       5 model = nn.Sequential(
#       6     Linear(28*28, 256),
#       7     ReLU(),
#    (...)
#      10     Linear(128, 10)
#      11 )
# ---> 12 train(model, loader, lr=0.1, epochs=5, weight_decay=1e-4)
#
# Cell In[6], line 11, in train(model, loader, lr, epochs, weight_decay, device)
#       9 xb,yb = xb.to(device), yb.to(device)
#      10 opt.zero_grad()
# ---> 11 out = model(xb)
#      12 loss = loss_fn(out, yb)
#      13 loss.backward()
#
# File c:\Users\sankl\OneDrive\Documents\neuro-lab\venv\lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\sankl\OneDrive\Documents\neuro-lab\venv\lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\sankl\OneDrive\Documents\neuro-lab\venv\lib\site-packages\torch\nn\modules\container.py:250, in Sequential.forward(self, input)
#     246 """
#     247 Runs the forward pass.
#     248 """
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File c:\Users\sankl\OneDrive\Documents\neuro-lab\venv\lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\sankl\OneDrive\Documents\neuro-lab\venv\lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# Cell In[5], line 9, in Linear.forward(self, x)
#       8 def forward(self, x):
# ----> 9     return LinearFn.apply(x, self.w, self.b)
#
# File c:\Users\sankl\OneDrive\Documents\neuro-lab\venv\lib\site-packages\torch\autograd\function.py:581, in Function.apply(cls, *args, **kwargs)
#     578 if not torch._C._are_functorch_transforms_active():
#     579     # See NOTE: [functorch vjp and autograd interaction]
#     580     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 581     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     583 if not is_setup_ctx_defined:
#     584     raise RuntimeError(
#     585         "In order to use an autograd.Function with functorch transforms "
#     586         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     587         "staticmethod. For more details, please see "
#     588         "https://pytorch.org/docs/main/notes/extending.func.html"
#     589     )
#
# Cell In[4], line 6, in LinearFn.forward(ctx, x, w, b)
#       3 @staticmethod
#       4 def forward(ctx, x, w, b):
#       5     ctx.save_for_backward(x, w, b)
# ----> 6     return x @ w.t() + b
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (3584x28 and 784x256)
